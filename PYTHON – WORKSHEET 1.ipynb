# %% [markdown]
# 1. Which of the following operators is used to calculate remainder in a division?

# %% [markdown]
# Solution: C) %

# %% [markdown]
# 2. In python 2//3 is equal to?

# %%
2//3
# Out:
# 0

# %% [markdown]
# Solution: B) 0

# %% [markdown]
# 3. In python, 6<<2 is equal to?

# %%
6<<2
# Out:
# 24

# %% [markdown]
# Solution: C) 24

# %% [markdown]
# 4. In python, 6&2 will give which of the following as output?

# %%
6&2
# Out:
# 2

# %% [markdown]
# Solution: A) 2

# %% [markdown]
# 5. In python, 6|2 will give which of the following as output?

# %%
6|2
# Out:
# 6

# %% [markdown]
# Solution : D) 6

# %% [markdown]
# 6. What does the finally keyword denotes in python?

# %% [markdown]
# C) the finally block will be executed no matter if the try block raises an error or not.

# %% [markdown]
# 7. What does raise keyword is used for in python?

# %% [markdown]
# Solution : A)  It is used to raise an exception.

# %% [markdown]
# 8. Which of the following is a common use case of yield keyword in python?

# %% [markdown]
# Solution: C)  in defining a generator

# %% [markdown]
# 9. Which of the following are the valid variable names?

# %% [markdown]
# Solutions: A)  _abc    &      C) abc2

# %% [markdown]
# 10. Which of the following are the keywords in python?

# %% [markdown]
# Solution : A) yield  &  B) raise

# %% [markdown]
# 11. Write a python program to find the factorial of a number.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
n=int(input("Input a number to compute the factiorial : "))
print(factorial(n))
# Out:
# Input a number to compute the factiorial : 5
# 120

# %% [markdown]
# 12. Write a python program to find whether a number is prime or composite.

# %%
num = int(input("Enter any number : "))
if num > 1:
    for i in range(2, num):
        if (num % i) == 0:
            print(num, "is NOT a prime number")
            break
    else:
        print(num, "is a PRIME number")
elif num == 0 or 1:
    print(num, "is a neither prime NOR composite number")
else:
    print(num, "is NOT a prime number it is a COMPOSITE number")
# Out:
# Enter any number : 13
# 13 is a PRIME number

# %% [markdown]
# 13. Write a python program to check whether a given string is palindrome or not.

# %%
def isPalindrome(s):
    return s == s[::-1] 
s = "malayalam" 
ans = isPalindrome(s)   
if ans:     
    print("Yes It is a Palindrome") 
else:     
    print("No It is not a Palindrome")
# Out:
# Yes It is a Palindrome

# %% [markdown]
# 14. Write a Python program to get the third side of right-angled triangle from two given sides.

# %%
def pythagoras(opposite_side,adjacent_side,hypotenuse):
        if opposite_side == str("x"):
            return ("Opposite = " + str(((hypotenuse**2) - (adjacent_side**2))**0.5))
        elif adjacent_side == str("x"):
            return ("Adjacent = " + str(((hypotenuse**2) - (opposite_side**2))**0.5))
        elif hypotenuse == str("x"):
            return ("Hypotenuse = " + str(((opposite_side**2) + (adjacent_side**2))**0.5))
        else:
            return "You know the answer!"
    
print(pythagoras(3,4,'x'))
print(pythagoras(3,'x',5))
print(pythagoras('x',4,5))
print(pythagoras(3,4,5))
# Out:
# Hypotenuse = 5.0
# Adjacent = 4.0
# Opposite = 3.0
# You know the answer!

# %%
test_str = "iousafhkjdsjckxhvcuighvovh"
all_freq = {}
for i in test_str:
    if i in all_freq:
        all_freq[i] += 1
    else:
        all_freq[i] = 1
print ("Count of all characters is :\n "+  str(all_freq))
# Out:
# Count of all characters is :
#  {'i': 2, 'o': 2, 'u': 2, 's': 2, 'a': 1, 'f': 1, 'h': 4, 'k': 2, 'j': 2, 'd': 1, 'c': 2, 'x': 1, 'v': 3, 'g': 1}
